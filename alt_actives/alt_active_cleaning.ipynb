# %% [markdown]
# ## Cleaning Alt Actives
# The alt active dataset is cleaned and canonical smiles are extracted

# %%
# importing libraries

import pandas as pd
import numpy as np
import pubchempy as pcp
import time

# %%
# reading and importing active dataset

df = pd.read_csv("alt_active.csv")
df
# Out:
#           sid        cid sidsrcname      sidextid  \
# 0      851380     653949      MLSMR  MLS000028188
# 1      855880     969516      MLSMR  MLS000069631
# 2      856745     658104      MLSMR  MLS000069179
# 3      857055     100641      MLSMR  MLS000080824
# 4      857094     629074      MLSMR  MLS000037792
# ..        ...        ...        ...           ...
# 215  24833322    2463883      MLSMR  MLS000761068
# 216  24834596    3934060      MLSMR  MLS000772776
# 217  24836078  135440580      MLSMR  MLS000760005
# 218  24841413    6451074      MLSMR  MLS000876965
# 219  24841426     160115      MLSMR  MLS000876993
#
#                                            subssynonym  sidmdate   depdate  \
# 0    MLS000028188|4-Chloro-7-ethylamino-chromen-2-o...  20120301  20050604
# 1                   curcumin|MLS000069631|SMR000058237  20210728  20050629
# 2                            MLS000069179|SMR000039036  20190115  20050629
# 3                            MLS000080824|SMR000034073  20120301  20050629
# 4                            MLS000037792|SMR000039459  20210728  20050629
# ..                                                 ...       ...       ...
# 215                          MLS000761068|SMR000372367  20210728  20070705
# 216                          MLS000772776|SMR000377356  20190115  20070705
# 217                          MLS000760005|SMR000370107  20210728  20070705
# 218                          MLS000876965|SMR000440628  20120301  20070705
# 219                          MLS000876993|SMR000440611  20190115  20070705
#
#                                         depcatg  annotation activity
# 0    Governmental Organizations|NIH Initiatives         NaN   Active
# 1    Governmental Organizations|NIH Initiatives         NaN   Active
# 2    Governmental Organizations|NIH Initiatives         NaN   Active
# 3    Governmental Organizations|NIH Initiatives         NaN   Active
# 4    Governmental Organizations|NIH Initiatives         NaN   Active
# ..                                          ...         ...      ...
# 215  Governmental Organizations|NIH Initiatives         NaN   Active
# 216  Governmental Organizations|NIH Initiatives         NaN   Active
# 217  Governmental Organizations|NIH Initiatives         NaN   Active
# 218  Governmental Organizations|NIH Initiatives         NaN   Active
# 219  Governmental Organizations|NIH Initiatives         NaN   Active
#
# [220 rows x 10 columns]

# %%
# checking for missing values in all columns

df.isnull().sum()
# Out:
# sid              0
# cid              0
# sidsrcname       0
# sidextid         0
# subssynonym      0
# sidmdate         0
# depdate          0
# depcatg          0
# annotation     220
# activity         0
# dtype: int64

# %%
# checking all column names

df.columns
# Out:
# Index(['sid', 'cid', 'sidsrcname', 'sidextid', 'subssynonym', 'sidmdate',
#        'depdate', 'depcatg', 'annotation', 'activity'],
#       dtype='object')

# %%
# removing 'unecessary' columns

df = df.drop(['sid', 'sidsrcname', 'sidextid', 'subssynonym', 'sidmdate', 'depdate', 'depcatg', 'annotation'], axis = 'columns')
df
# Out:
#            cid activity
# 0       653949   Active
# 1       969516   Active
# 2       658104   Active
# 3       100641   Active
# 4       629074   Active
# ..         ...      ...
# 215    2463883   Active
# 216    3934060   Active
# 217  135440580   Active
# 218    6451074   Active
# 219     160115   Active
#
# [220 rows x 2 columns]

# %%
# extracting canonical smiles and compound names from pubchem database

cid_list = np.array(df.cid)

start = time.time()

smiles_df = pcp.get_properties(['CanonicalSMILES', 'IUPACname'], np.nditer(cid_list), 'cid', as_dataframe = True)

end = time.time()

print("The time take in seconds for extraction of canonical smiles is :  ", end-start)
smiles_df
# Out:
# The time take in seconds for extraction of canonical smiles is :   1.9265408515930176
#                                              CanonicalSMILES  \
# CID
# 653949                       CCNC1=CC2=C(C=C1)C(=CC(=O)O2)Cl
# 969516     COC1=C(C=CC(=C1)C=CC(=O)CC(=O)C=CC2=CC(=C(C=C2...
# 658104     COC(=O)C1=CC=C(O1)C2=C(C3=C(S2)N=C(C4=C3CCCC4)...
# 100641                     C1=CC2=C(C=C1N)OC(=O)C=C2C(F)(F)F
# 629074     C1=CC=C(C=C1)C2=NC3=C(C(=C2)C4=CC=CO4)C(=C(S3)...
# ...                                                      ...
# 2463883    CC1=CC(=CC=C1)N2C(=O)C3=CC=CC=C3C(=CC4=CC=C(C=...
# 3934060    CC(C)CN1C2=C(C(=O)NC1=O)N(C(=N2)C3=CC=C(O3)C4=...
# 135440580     CC(=NNC1=CC=C(C=C1)[N+](=O)[O-])C2=CC=C(C=C2)O
# 6451074    CCC(C)C=C(C)C=CC1=CC2=CC(=O)C3(C(C2=CO1)C(C(=O...
# 160115     CC1CC(=O)C2=C(O1)C=C3C(=C2O)C(=CC(=C3C4=C(C=C(...
#
#                                                    IUPACName
# CID
# 653949                  4-chloro-7-(ethylamino)chromen-2-one
# 969516     (1E,6E)-1,7-bis(4-hydroxy-3-methoxyphenyl)hept...
# 658104     methyl 5-(1-amino-5-morpholin-4-yl-6,7,8,9-tet...
# 100641              7-amino-4-(trifluoromethyl)chromen-2-one
# 629074     3-amino-4-(furan-2-yl)-6-phenylthieno[2,3-b]py...
# ...                                                      ...
# 2463883    4-[(Z)-[2-(3-methylphenyl)-1,3-dioxoisoquinoli...
# 3934060    8-[5-(2-bromo-4-nitrophenyl)furan-2-yl]-7-(2-m...
# 135440580  4-[(E)-C-methyl-N-(4-nitroanilino)carbonimidoy...
# 6451074    (6aR,9R,9aR)-9-acetyl-3-[(1E,3E,5S)-3,5-dimeth...
# 160115     5,6,8-trihydroxy-2-methyl-9-(5,6,8-trihydroxy-...
#
# [220 rows x 2 columns]

# %%
# removing indexes

smiles_df = smiles_df.reset_index(drop = True)
smiles_df
# Out:
#                                        CanonicalSMILES  \
# 0                      CCNC1=CC2=C(C=C1)C(=CC(=O)O2)Cl
# 1    COC1=C(C=CC(=C1)C=CC(=O)CC(=O)C=CC2=CC(=C(C=C2...
# 2    COC(=O)C1=CC=C(O1)C2=C(C3=C(S2)N=C(C4=C3CCCC4)...
# 3                    C1=CC2=C(C=C1N)OC(=O)C=C2C(F)(F)F
# 4    C1=CC=C(C=C1)C2=NC3=C(C(=C2)C4=CC=CO4)C(=C(S3)...
# ..                                                 ...
# 215  CC1=CC(=CC=C1)N2C(=O)C3=CC=CC=C3C(=CC4=CC=C(C=...
# 216  CC(C)CN1C2=C(C(=O)NC1=O)N(C(=N2)C3=CC=C(O3)C4=...
# 217     CC(=NNC1=CC=C(C=C1)[N+](=O)[O-])C2=CC=C(C=C2)O
# 218  CCC(C)C=C(C)C=CC1=CC2=CC(=O)C3(C(C2=CO1)C(C(=O...
# 219  CC1CC(=O)C2=C(O1)C=C3C(=C2O)C(=CC(=C3C4=C(C=C(...
#
#                                              IUPACName
# 0                 4-chloro-7-(ethylamino)chromen-2-one
# 1    (1E,6E)-1,7-bis(4-hydroxy-3-methoxyphenyl)hept...
# 2    methyl 5-(1-amino-5-morpholin-4-yl-6,7,8,9-tet...
# 3             7-amino-4-(trifluoromethyl)chromen-2-one
# 4    3-amino-4-(furan-2-yl)-6-phenylthieno[2,3-b]py...
# ..                                                 ...
# 215  4-[(Z)-[2-(3-methylphenyl)-1,3-dioxoisoquinoli...
# 216  8-[5-(2-bromo-4-nitrophenyl)furan-2-yl]-7-(2-m...
# 217  4-[(E)-C-methyl-N-(4-nitroanilino)carbonimidoy...
# 218  (6aR,9R,9aR)-9-acetyl-3-[(1E,3E,5S)-3,5-dimeth...
# 219  5,6,8-trihydroxy-2-methyl-9-(5,6,8-trihydroxy-...
#
# [220 rows x 2 columns]

# %%
# creating a csv of canonical smiles

smiles_df['CanonicalSMILES'].to_csv("alt_active_smiles.csv", index = False)

# %%
# final dataframe with all necessary features

final_df = pd.concat([df, smiles_df], axis = 1)
final_df
# Out:
#            cid activity                                    CanonicalSMILES  \
# 0       653949   Active                    CCNC1=CC2=C(C=C1)C(=CC(=O)O2)Cl
# 1       969516   Active  COC1=C(C=CC(=C1)C=CC(=O)CC(=O)C=CC2=CC(=C(C=C2...
# 2       658104   Active  COC(=O)C1=CC=C(O1)C2=C(C3=C(S2)N=C(C4=C3CCCC4)...
# 3       100641   Active                  C1=CC2=C(C=C1N)OC(=O)C=C2C(F)(F)F
# 4       629074   Active  C1=CC=C(C=C1)C2=NC3=C(C(=C2)C4=CC=CO4)C(=C(S3)...
# ..         ...      ...                                                ...
# 215    2463883   Active  CC1=CC(=CC=C1)N2C(=O)C3=CC=CC=C3C(=CC4=CC=C(C=...
# 216    3934060   Active  CC(C)CN1C2=C(C(=O)NC1=O)N(C(=N2)C3=CC=C(O3)C4=...
# 217  135440580   Active     CC(=NNC1=CC=C(C=C1)[N+](=O)[O-])C2=CC=C(C=C2)O
# 218    6451074   Active  CCC(C)C=C(C)C=CC1=CC2=CC(=O)C3(C(C2=CO1)C(C(=O...
# 219     160115   Active  CC1CC(=O)C2=C(O1)C=C3C(=C2O)C(=CC(=C3C4=C(C=C(...
#
#                                              IUPACName
# 0                 4-chloro-7-(ethylamino)chromen-2-one
# 1    (1E,6E)-1,7-bis(4-hydroxy-3-methoxyphenyl)hept...
# 2    methyl 5-(1-amino-5-morpholin-4-yl-6,7,8,9-tet...
# 3             7-amino-4-(trifluoromethyl)chromen-2-one
# 4    3-amino-4-(furan-2-yl)-6-phenylthieno[2,3-b]py...
# ..                                                 ...
# 215  4-[(Z)-[2-(3-methylphenyl)-1,3-dioxoisoquinoli...
# 216  8-[5-(2-bromo-4-nitrophenyl)furan-2-yl]-7-(2-m...
# 217  4-[(E)-C-methyl-N-(4-nitroanilino)carbonimidoy...
# 218  (6aR,9R,9aR)-9-acetyl-3-[(1E,3E,5S)-3,5-dimeth...
# 219  5,6,8-trihydroxy-2-methyl-9-(5,6,8-trihydroxy-...
#
# [220 rows x 4 columns]

# %% [markdown]
# Rearranging features to put 'activity' at the last column

# %%
name = final_df.pop('IUPACName')
final_df.insert(1, 'cmpdname', name)

act = final_df.pop('activity')
final_df.insert(3, 'activity', act)
final_df
# Out:
#            cid                                           cmpdname  \
# 0       653949               4-chloro-7-(ethylamino)chromen-2-one
# 1       969516  (1E,6E)-1,7-bis(4-hydroxy-3-methoxyphenyl)hept...
# 2       658104  methyl 5-(1-amino-5-morpholin-4-yl-6,7,8,9-tet...
# 3       100641           7-amino-4-(trifluoromethyl)chromen-2-one
# 4       629074  3-amino-4-(furan-2-yl)-6-phenylthieno[2,3-b]py...
# ..         ...                                                ...
# 215    2463883  4-[(Z)-[2-(3-methylphenyl)-1,3-dioxoisoquinoli...
# 216    3934060  8-[5-(2-bromo-4-nitrophenyl)furan-2-yl]-7-(2-m...
# 217  135440580  4-[(E)-C-methyl-N-(4-nitroanilino)carbonimidoy...
# 218    6451074  (6aR,9R,9aR)-9-acetyl-3-[(1E,3E,5S)-3,5-dimeth...
# 219     160115  5,6,8-trihydroxy-2-methyl-9-(5,6,8-trihydroxy-...
#
#                                        CanonicalSMILES activity
# 0                      CCNC1=CC2=C(C=C1)C(=CC(=O)O2)Cl   Active
# 1    COC1=C(C=CC(=C1)C=CC(=O)CC(=O)C=CC2=CC(=C(C=C2...   Active
# 2    COC(=O)C1=CC=C(O1)C2=C(C3=C(S2)N=C(C4=C3CCCC4)...   Active
# 3                    C1=CC2=C(C=C1N)OC(=O)C=C2C(F)(F)F   Active
# 4    C1=CC=C(C=C1)C2=NC3=C(C(=C2)C4=CC=CO4)C(=C(S3)...   Active
# ..                                                 ...      ...
# 215  CC1=CC(=CC=C1)N2C(=O)C3=CC=CC=C3C(=CC4=CC=C(C=...   Active
# 216  CC(C)CN1C2=C(C(=O)NC1=O)N(C(=N2)C3=CC=C(O3)C4=...   Active
# 217     CC(=NNC1=CC=C(C=C1)[N+](=O)[O-])C2=CC=C(C=C2)O   Active
# 218  CCC(C)C=C(C)C=CC1=CC2=CC(=O)C3(C(C2=CO1)C(C(=O...   Active
# 219  CC1CC(=O)C2=C(O1)C=C3C(=C2O)C(=CC(=C3C4=C(C=C(...   Active
#
# [220 rows x 4 columns]

# %% [markdown]
# Now activity column is the last

# %%
# saving the final_df as a .csv file

final_df.to_csv("alt_active_final.csv", index = False)
